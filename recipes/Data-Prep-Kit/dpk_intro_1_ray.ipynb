# %% [markdown]
# # Data Prep Kit Demo 1 - Ray Version
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujee/granite-code-cookbook/blob/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/dpk_intro_1_ray.ipynb)
#
#
# This notebook will introduce DPK and showcase some of it's capabilities.
#
# Here is the workflow
#
# ![](https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/media/data-prep-kit-3-workflow.png)
#
# References
# - [Data prep kit](https://ibm.github.io/data-prep-kit)  is an open source framework that helps with data wrangling.
# - [github repo](https://github.com/IBM/data-prep-kit)

# %% [markdown]
# ## How to run this notebook
#
# Two options:
#
# - **Option 1 - Google Colab:** easiest option.  no setup required.  Click this link to open this on google colab.  [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujee/granite-code-cookbook/blob/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/dpk_intro_1_ray.ipynb)
# - **Option 2 - Local python dev environment:**  Setup using this guide: [setting up python dev environment](setup-python-dev-env.md)
#
# The notebook will work as in both environments

# %% [markdown]
# ## Step-1: Inspect the Data
#
# We will use simple PDFs about Solar system.  The files are [here](https://github.com/sujee/granite-code-cookbook/blob/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/data/solar-system)
#
# - [earth.pdf](https://github.com/sujee/granite-code-cookbook/blob/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/data/solar-system/earth.pdf)
# - [mars.pdf](https://github.com/sujee/granite-code-cookbook/blob/recipe/data-prep-kit-intro/recipes/Data-Prep-Kit/data/solar-system/mars.pdf)
#
# These PDF files are created from markdown files using the following command
#
# ```bash
# pandoc  earth.md  -o earth.pdf
# pandoc  mars.md  -o mars.pdf
# ```

# %% [markdown]
# ## Step-2: Figure out Runtime Environment
#
# ### 2.1 - Determine runtime
#
# Determine if we are running on Google colab or local python environment

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
   print("Running in Colab")
   RUNNING_IN_COLAB = True
else:
   print("NOT in Colab")
   RUNNING_IN_COLAB = False
# Out:
# Running in Colab

# %% [markdown]
# ### 2.2 -Download Data if running on Google Colab

# %%
if RUNNING_IN_COLAB:
    # !mkdir -p 'data/solar-system'
    # !wget -O 'data/solar-system/earth.pdf'  'https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/data/solar-system/earth.pdf'
    # !wget -O 'data/solar-system/mars.pdf'  'https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/data/solar-system/mars.pdf'
    # !wget -O 'utils.py'  'https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/utils.py'
# Out:
# --2024-09-26 07:18:18--  https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/data/solar-system/earth.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58535 (57K) [application/octet-stream]
# Saving to: ‘data/solar-system/earth.pdf’
#
# data/solar-system/e 100%[===================>]  57.16K  --.-KB/s    in 0.01s
#
# 2024-09-26 07:18:18 (4.12 MB/s) - ‘data/solar-system/earth.pdf’ saved [58535/58535]
#
# --2024-09-26 07:18:18--  https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/data/solar-system/mars.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57872 (57K) [application/octet-stream]
# Saving to: ‘data/solar-system/mars.pdf’
#
# data/solar-system/m 100%[===================>]  56.52K  --.-KB/s    in 0.01s
#
# 2024-09-26 07:18:18 (4.20 MB/s) - ‘data/solar-system/mars.pdf’ saved [57872/57872]
#
# --2024-09-26 07:18:18--  https://raw.githubusercontent.com/sujee/granite-code-cookbook/recipe/data-prep-kit-1-intro/recipes/Data-Prep-Kit/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1856 (1.8K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   1.81K  --.-KB/s    in 0s
#
# 2024-09-26 07:18:19 (19.4 MB/s) - ‘utils.py’ saved [1856/1856]

# %% [markdown]
# ### 2.3 - Install dependencies if running on Google Colab

# %%
if RUNNING_IN_COLAB:
    ! pip install  --default-timeout=100  \
        data-prep-toolkit-transforms-ray==0.2.1.dev3 \
        deepsearch-toolkit
# Out:
# Collecting data-prep-toolkit-transforms-ray==0.2.1.dev3
#   Downloading data_prep_toolkit_transforms_ray-0.2.1.dev3-py3-none-any.whl.metadata (3.2 kB)
# Collecting deepsearch-toolkit
#   Downloading deepsearch_toolkit-1.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting data-prep-toolkit-ray>=0.2.1.dev3 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading data_prep_toolkit_ray-0.2.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting data-prep-toolkit-transforms>=0.2.1.dev3 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading data_prep_toolkit_transforms-0.2.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting parameterized (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting tqdm==4.66.3 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.2 MB/s eta 0:00:00
# Collecting mmh3==4.1.0 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting xxhash==3.4.1 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.13.1)
# Requirement already satisfied: networkx==3.3 in /usr/local/lib/python3.10/dist-packages (from data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.3)
# Collecting colorlog==6.8.2 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting func-timeout==4.3.5 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pandas==2.2.2 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting emerge-viz==2.0.0 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading emerge_viz-2.0.0-py3-none-any.whl.metadata (33 kB)
# Collecting scancode-toolkit==32.1.0 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading scancode_toolkit-32.1.0-cp310-none-any.whl.metadata (16 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.44.0)
# Collecting autopep8 (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading autopep8-2.3.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting coloredlogs (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting interrogate (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading interrogate-1.7.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.26.4)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.11.0)
# Collecting py (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting pycodestyle (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pylint (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pylint-3.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.1.4)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.16)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (6.0.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.9.0)
# Collecting PyDriller (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading PyDriller-2.6-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.10/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2024.1)
# Requirement already satisfied: Beautifulsoup4>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (4.12.3)
# Collecting boolean.py>=4.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading boolean.py-4.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: chardet>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (5.2.0)
# Requirement already satisfied: click!=7.0,>=6.7 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (8.1.7)
# Collecting colorama>=0.3.9 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting commoncode>=31.0.3 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading commoncode-32.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting container-inspector>=31.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading container_inspector-33.0.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting debian-inspector>=31.1.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading debian_inspector-31.1.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting dparse2>=0.7.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading dparse2-0.7.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting fasteners (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting fingerprints>=0.6.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading fingerprints-1.2.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting ftfy>=6.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading ftfy-6.2.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting gemfileparser2>=0.9.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading gemfileparser2-0.9.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (8.5.0)
# Collecting intbitset>=3.0.2 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading intbitset-3.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (4.7 kB)
# Collecting jaraco.functools (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading jaraco.functools-4.0.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting javaproperties>=0.5 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading javaproperties-0.8.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jinja2>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.1.4)
# Collecting jsonstreams>=0.5.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading jsonstreams-0.6.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting license-expression>=30.1.1 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading license_expression-30.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (4.9.4)
# Requirement already satisfied: MarkupSafe>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.1.5)
# Collecting packageurl-python>=0.9.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading packageurl_python-0.15.6-py3-none-any.whl.metadata (5.1 kB)
# Collecting packvers>=21.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading packvers-21.5-py3-none-any.whl.metadata (15 kB)
# Collecting parameter-expansion-patched>=0.3.1 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading parameter_expansion_patched-0.3.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting pdfminer.six>=20200101 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Collecting pefile>=2020.1.1 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pefile-2024.8.26-py3-none-any.whl.metadata (1.4 kB)
# Collecting pkginfo2>=30.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pkginfo2-30.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting pip-requirements-parser>=32.0.1 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pip_requirements_parser-32.0.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pluggy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.5.0)
# Collecting plugincode>=32.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading plugincode-32.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting publicsuffix2 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading publicsuffix2-2.20191221-py2.py3-none-any.whl.metadata (13 kB)
# Collecting pyahocorasick>=2.0.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Collecting pygmars>=0.7.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pygmars-0.9.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.18.0)
# Collecting pymaven-patch>=0.2.8 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pymaven_patch-0.3.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.32.3)
# Collecting saneyaml>=0.6.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading saneyaml-0.6.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting spdx-tools==0.8.2 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading spdx_tools-0.8.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: text-unidecode>=1.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.3)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.10.2)
# Collecting urlpy (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading urlpy-0.5-py2.py3-none-any.whl.metadata (893 bytes)
# Collecting xmltodict>=0.11.0 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting typecode>=30.0.1 (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading typecode-30.0.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting extractcode>=31.0.0 (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading extractcode-31.0.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: attrs!=20.1.0,>=18.1 in /usr/local/lib/python3.10/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (24.2.0)
# Collecting rdflib (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting beartype (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading beartype-0.19.0-py3-none-any.whl.metadata (32 kB)
# Collecting uritools (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading uritools-4.0.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting ply (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting semantic-version (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi<2025.0.0,>=2024.07.04 in /usr/local/lib/python3.10/dist-packages (from deepsearch-toolkit) (2024.8.30)
# Collecting docling-core<2.0.0,>=1.1.2 (from deepsearch-toolkit)
#   Downloading docling_core-1.6.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: platformdirs<5.0.0,>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from deepsearch-toolkit) (4.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from deepsearch-toolkit) (2.9.2)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from deepsearch-toolkit)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from deepsearch-toolkit)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from deepsearch-toolkit) (1.16.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0.0,>=0.9.0->deepsearch-toolkit) (0.12.5)
# Collecting urllib3<2.0.0,>=1.26.8 (from deepsearch-toolkit)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.6 MB/s eta 0:00:00
# Collecting data-prep-toolkit>=0.2.1 (from data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading data_prep_toolkit-0.2.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting ray==2.24.0 (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading ray-2.24.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting fastapi>=0.110.2 (from data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.4.1)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.10/dist-packages (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.10.5)
# Collecting aiohttp-cors (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting opencensus (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.21.0)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (7.0.4)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading virtualenv-20.26.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.64.1)
# Collecting memray (from ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (19 kB)
# Collecting bs4==0.0.2 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting docling-ibm-models==1.1.7 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading docling_ibm_models-1.1.7-py3-none-any.whl.metadata (7.2 kB)
# Collecting deepsearch-glm==0.21.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading deepsearch_glm-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting docling==1.11.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading docling-1.11.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting docling-core<2.0.0,>=1.1.2 (from deepsearch-toolkit)
#   Downloading docling_core-1.3.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-core<0.12.0,>=0.11.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading llama_index_core-0.11.13.post1-py3-none-any.whl.metadata (2.4 kB)
# Collecting duckdb==0.10.1 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading duckdb-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (763 bytes)
# Collecting fasttext==0.9.2 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.21.4 in /usr/local/lib/python3.10/dist-packages (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.24.7)
# Collecting langcodes==3.3.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Collecting sentence-transformers==3.0.1 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers==4.38.2 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 7.4 MB/s eta 0:00:00
# Collecting presidio-analyzer>=2.2.355 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading presidio_analyzer-2.2.355-py3-none-any.whl.metadata (2.9 kB)
# Collecting presidio-anonymizer>=2.2.355 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading presidio_anonymizer-2.2.355-py3-none-any.whl.metadata (8.2 kB)
# Collecting flair>=0.14.0 (from data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading flair-0.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting json-schema-for-humans<2.0.0,>=1.0.0 (from docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading json_schema_for_humans-1.0.2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyproject-toml<0.0.11,>=0.0.10 (from docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading pyproject_toml-0.0.10-py3-none-any.whl.metadata (642 bytes)
# Requirement already satisfied: docutils!=0.21 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.18.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.7.1)
# Collecting netwulf<0.2.0,>=0.1.5 (from deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading netwulf-0.1.5.tar.gz (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numerize<0.13,>=0.12 (from deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading numerize-0.12.tar.gz (2.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (13.8.1)
# Collecting docling-parse<2.0.0,>=1.2.0 (from docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading docling_parse-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting easyocr<2.0,>=1.7 (from docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting pyarrow<17.0.0,>=16.1.0 (from docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pypdfium2<5.0.0,>=4.30.0 (from docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.4 MB/s eta 0:00:00
# Collecting rtree<2.0.0,>=1.3.0 (from docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting scipy>=1.12.0 (from data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.3 MB/s eta 0:00:00
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting mean_average_precision<2022.0.0.0,>=2021.4.26.0 (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading mean_average_precision-2021.4.26.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting onnxruntime<2.0.0,>=1.16.2 (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (4.10.0.84)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.4.1+cu121)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models==1.1.7->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.19.1+cu121)
# Collecting pybind11>=2.2 (from fasttext==0.9.2->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext==0.9.2->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (71.0.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.2->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2024.9.11)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.38.2->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.2->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.4.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.3->deepsearch-toolkit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.3->deepsearch-toolkit) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.3->deepsearch-toolkit) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.10)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.9.0->typer[all]<1.0.0,>=0.9.0->deepsearch-toolkit) (1.5.4)
# WARNING: typer 0.12.5 does not provide the extra 'all'
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from Beautifulsoup4>=4.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.6)
# Collecting dockerfile-parse (from container-inspector>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading dockerfile_parse-2.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting boto3==1.34.69 (from data-prep-toolkit>=0.2.1->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading boto3-1.34.69-py3-none-any.whl.metadata (6.6 kB)
# Collecting argparse (from data-prep-toolkit>=0.2.1->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting botocore<1.35.0,>=1.34.69 (from boto3==1.34.69->data-prep-toolkit>=0.2.1->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading botocore-1.34.162-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3==1.34.69->data-prep-toolkit>=0.2.1->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3==1.34.69->data-prep-toolkit>=0.2.1->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# WARNING: Package 'extractcode' has an invalid Requires-Python: Invalid specifier: '>=3.6.*'
# Collecting extractcode-7z>=16.5.210525 (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading extractcode_7z-16.5.210531-py3-none-manylinux1_x86_64.whl.metadata (594 bytes)
# Collecting extractcode-libarchive>=3.5.1.210525 (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading extractcode_libarchive-3.5.1.210531-py3-none-manylinux1_x86_64.whl.metadata (576 bytes)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.110.2->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting normality<=3.0.0,>=2.0.0 (from fingerprints>=0.6.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading normality-2.5.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting conllu<5.0.0,>=4.0 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl.metadata (19 kB)
# Collecting deprecated>=1.2.13 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (5.2.0)
# Collecting langdetect>=1.0.9 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 33.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.10/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (10.5.0)
# Collecting mpld3>=0.3 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading mpld3-0.5.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting pptree>=3.1 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad>=0.2.0 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting segtok>=1.5.11 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading segtok-1.5.11-py3-none-any.whl.metadata (9.0 kB)
# Collecting sqlitedict>=2.0.0 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting wikipedia-api>=0.5.7 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading wikipedia_api-0.7.1.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting semver<4.0.0,>=3.0.0 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading semver-3.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting bioc<3.0.0,>=2.0.0 (from flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading bioc-2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.2.13)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2024.6.1)
# Collecting dataclasses-json<0.6.0,>=0.5.6 (from json-schema-for-humans<2.0.0,>=1.0.0->docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting htmlmin<0.2.0,>=0.1.12 (from json-schema-for-humans<2.0.0,>=1.0.0->docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting markdown2<3.0.0,>=2.4.1 (from json-schema-for-humans<2.0.0,>=1.0.0->docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading markdown2-2.5.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.24.0->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.20.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.0.35)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting httpx (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.6.0)
# Collecting nltk>3.8.1 (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.16.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20200101->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (43.0.1)
# Collecting phonenumbers<9.0.0,>=8.12 (from presidio-analyzer>=2.2.355->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading phonenumbers-8.13.46-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer>=2.2.355->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.7.6)
# Collecting tldextract (from presidio-analyzer>=2.2.355->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tldextract-5.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core (from presidio-anonymizer>=2.2.355->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# Collecting pycryptodome>=3.10.1 (from presidio-anonymizer>=2.2.355->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm==0.21.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.5.0)
# Collecting binaryornot (from typecode>=30.0.1->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting typecode-libmagic>=5.39.210223 (from typecode[full]>=30.0.1->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading typecode_libmagic-5.39.210531-py3-none-manylinux1_x86_64.whl.metadata (700 bytes)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.0.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (3.20.2)
# Collecting gitpython (from PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: types-pytz in /usr/local/lib/python3.10/dist-packages (from PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2024.2.0.20240913)
# Collecting lizard (from PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading lizard-1.17.10-py2.py3-none-any.whl.metadata (15 kB)
# Collecting astroid<=3.4.0-dev0,>=3.3.4 (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading astroid-3.3.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting isort!=5.13.0,<6,>=4.2.5 (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting mccabe<0.8,>=0.6 (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting tomlkit>=0.10.1 (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting dill>=0.2 (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[default]==2.24.0->data-prep-toolkit-ray>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (4.0.3)
# Collecting intervaltree (from bioc<3.0.0,>=2.0.0->flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt (from bioc<3.0.0,>=2.0.0->flair>=0.14.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20200101->scancode-toolkit==32.1.0->data-prep-toolkit-transforms-ray==0.2.1.dev3) (1.17.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.6->json-schema-for-humans<2.0.0,>=1.0.0->docling-core<2.0.0,>=1.1.2->deepsearch-toolkit)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (0.24.0)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading python_bidi-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3) (2.0.6)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling==1.11.0->data-prep-toolkit-transforms>=0.2.1.dev3->data-prep-toolkit-transforms-ray==0.2.1.dev3)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# ...
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 62.1 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl (14 kB)
# Downloading typecode_libmagic-5.39.210531-py3-none-manylinux1_x86_64.whl (539 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.5/539.5 kB 30.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading virtualenv-20.26.5-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 63.0 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading azure_core-1.31.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.4/197.4 kB 13.9 MB/s eta 0:00:00
# Downloading beartype-0.19.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.7 MB/s eta 0:00:00
# Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 13.5 MB/s eta 0:00:00
# Downloading dockerfile_parse-2.0.1-py2.py3-none-any.whl (14 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 16.6 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.1 MB/s eta 0:00:00
# Downloading lizard-1.17.10-py2.py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 4.5 MB/s eta 0:00:00
# Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 71.4 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.3 MB/s eta 0:00:00
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.7 MB/s eta 0:00:00
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 29.4 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 8.7 MB/s eta 0:00:00
# Downloading uritools-4.0.3-py3-none-any.whl (10 kB)
# Downloading banal-1.0.6-py2.py3-none-any.whl (6.1 kB)
# Downloading botocore-1.34.162-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 25.4 MB/s eta 0:00:00
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 28.8 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.5 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 10.3 MB/s eta 0:00:00
# Downloading textual-0.81.0-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.4/596.4 kB 34.1 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 21.2 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 51.2 MB/s eta 0:00:00
# Downloading python_bidi-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.3/281.3 kB 20.1 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: func-timeout, fasttext, htmlmin, langdetect, netwulf, numerize, pptree, sqlitedict, wikipedia-api, docopt, intervaltree
#   Building wheel for func-timeout (setup.py) ... done
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15077 sha256=2c2581307e6fb8d1fb8abfd46a638a3c8cf626f86091aefae40982ec809bad82
#   Stored in directory: /root/.cache/pip/wheels/3f/83/19/b5552bb9630e353f7c5b15be44bf10900afe1abbbfcf536afd
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4284414 sha256=274ce5b2aaf4a5744c8ae3e9427e160fd9c5af611ddaffb9759f432261b243c0
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=f8c3f32900983d384cae8c42957fc2cf89c5cdc88777de25df86ca7bb092bd80
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=ee49c62ca39a47071bf737303c18376bdf53b702180b8a112992c99861a187ae
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for netwulf (setup.py) ... done
#   Created wheel for netwulf: filename=netwulf-0.1.5-py3-none-any.whl size=237984 sha256=9d1adeea070e03c8b62c8cc7e4f600eb96ef5ef96d4fde554de935b634db2787
#   Stored in directory: /root/.cache/pip/wheels/04/f3/75/3ee8148fe5296ab40fc164cc09572b0e31255242ccee47b354
#   Building wheel for numerize (setup.py) ... done
#   Created wheel for numerize: filename=numerize-0.12-py3-none-any.whl size=3154 sha256=26cc9b1ab2ef9f68e1fc02993133ca618b8b1d8e345e37c5badd7a1e378396b5
#   Stored in directory: /root/.cache/pip/wheels/87/84/e1/9e30f2e3da6590acb0f1c03a806e2673d2f9e7f5bd2b11589a
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=e4358572d82d07dd5b800450bdde80e625903027b5ee0a18cff2c32d4fe471f4
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=2e1c414a9d1956887fee63ed349585857d72124f11f08ad4d980ef48da8b64e0
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.7.1-py3-none-any.whl size=14347 sha256=ec5282b1a2c10c61a3f48a61d8ed3b3288a3443b198e64723d72778cf4430c9d
#   Stored in directory: /root/.cache/pip/wheels/4c/96/18/b9201cc3e8b47b02b510460210cfd832ccf10c0c4dd0522962
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=ba9fdc55a48a4d73c1620c67f0bdc815d0fea6abd5d88a900d86c4564939c5d5
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26096 sha256=5a1ab56753d55d34a25fc6ea5a6bc48fd640cc88ccdc2218f7b4e51583c0631c
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built func-timeout fasttext htmlmin langdetect netwulf numerize pptree sqlitedict wikipedia-api docopt intervaltree
# Installing collected packages: typecode-libmagic, sqlitedict, python-bidi, pyclipper, py-spy, publicsuffix2, pptree, ply, pkginfo2, phonenumbers, parameter-expansion-patched, opencensus-context, numerize, ninja, mmh3, lizard, intbitset, htmlmin, func-timeout, filetype, extractcode-libarchive, extractcode-7z, docopt, distlib, dirtyjson, colorful, boolean.py, banal, argparse, xxhash, xmltodict, virtualenv, urlpy, urllib3, uritools, tqdm, tomlkit, tenacity, smmap, simplejson, semver, semantic-version, segtok, scipy, saneyaml, rtree, python-dotenv, pypdfium2, pygmars, pycryptodome, pycodestyle, pybind11, pyarrow, pyahocorasick, py, pip-requirements-parser, pefile, parameterized, packvers, packageurl-python, normality, mypy-extensions, mccabe, marshmallow, markdown2, license-expression, langdetect, langcodes, jsonstreams, jsonref, jsonlines, jmespath, javaproperties, jaraco.functools, isort, isodate, intervaltree, humanfriendly, h11, gemfileparser2, ftfy, fasteners, duckdb, docling-parse, dockerfile-parse, dill, deprecated, debian-inspector, conllu, colorlog, colorama, binaryornot, beartype, astroid, typing-inspect, starlette, rdflib, pylint, pandas, nltk, interrogate, httpcore, gitdb, fingerprints, fasttext, dparse2, coloredlogs, bs4, botocore, bioc, autopep8, wikipedia-api, tiktoken, spdx-tools, s3transfer, requests-file, pytorch-revgrad, pymaven-patch, pydantic-settings, pdfminer.six, onnxruntime, netwulf, mpld3, mean_average_precision, httpx, gitpython, fastapi, dataclasses-json, azure-core, tokenizers, tldextract, textual, ray, pyproject-toml, PyDriller, presidio-anonymizer, opencensus, llama-index-core, json-schema-for-humans, easyocr, docling-ibm-models, deepsearch-glm, commoncode, boto3, aiohttp-cors, transformers, plugincode, memray, emerge-viz, docling-core, data-prep-toolkit, container-inspector, typecode, sentence-transformers, presidio-analyzer, docling, deepsearch-toolkit, transformer-smaller-training-vocab, extractcode, data-prep-toolkit-ray, flair, scancode-toolkit, data-prep-toolkit-transforms, data-prep-toolkit-transforms-ray
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: langcodes
#     Found existing installation: langcodes 3.4.0
#     Uninstalling langcodes-3.4.0:
#       Successfully uninstalled langcodes-3.4.0
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.1.0
#     Uninstalling duckdb-1.1.0:
#       Successfully uninstalled duckdb-1.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.2.2 which is incompatible.
# Successfully installed PyDriller-2.6 aiohttp-cors-0.7.0 argparse-1.4.0 astroid-3.3.4 autopep8-2.3.1 azure-core-1.31.0 banal-1.0.6 beartype-0.19.0 binaryornot-0.4.4 bioc-2.1 boolean.py-4.0 boto3-1.34.69 botocore-1.34.162 bs4-0.0.2 colorama-0.4.6 coloredlogs-15.0.1 colorful-0.5.6 colorlog-6.8.2 commoncode-32.0.0 conllu-4.5.3 container-inspector-33.0.0 data-prep-toolkit-0.2.1 data-prep-toolkit-ray-0.2.1 data-prep-toolkit-transforms-0.2.1 data-prep-toolkit-transforms-ray-0.2.1.dev3 dataclasses-json-0.5.14 debian-inspector-31.1.0 deepsearch-glm-0.21.0 deepsearch-toolkit-1.0.1 deprecated-1.2.14 dill-0.3.8 dirtyjson-1.0.8 distlib-0.3.8 dockerfile-parse-2.0.1 docling-1.11.0 docling-core-1.3.0 docling-ibm-models-1.1.7 docling-parse-1.3.0 docopt-0.6.2 dparse2-0.7.0 duckdb-0.10.1 easyocr-1.7.2 emerge-viz-2.0.0 extractcode-31.0.0 extractcode-7z-16.5.210531 extractcode-libarchive-3.5.1.210531 fastapi-0.115.0 fasteners-0.19 fasttext-0.9.2 filetype-1.2.0 fingerprints-1.2.3 flair-0.14.0 ftfy-6.2.3 func-timeout-4.3.5 gemfileparser2-0.9.4 gitdb-4.0.11 gitpython-3.1.43 h11-0.14.0 htmlmin-0.1.12 httpcore-1.0.5 httpx-0.27.2 humanfriendly-10.0 intbitset-3.1.0 interrogate-1.7.0 intervaltree-3.1.0 isodate-0.6.1 isort-5.13.2 jaraco.functools-4.0.2 javaproperties-0.8.1 jmespath-1.0.1 json-schema-for-humans-1.0.2 jsonlines-3.1.0 jsonref-1.1.0 jsonstreams-0.6.0 langcodes-3.3.0 langdetect-1.0.9 license-expression-30.3.1 lizard-1.17.10 llama-index-core-0.11.13.post1 markdown2-2.5.0 marshmallow-3.22.0 mccabe-0.7.0 mean_average_precision-2021.4.26.0 memray-1.14.0 mmh3-4.1.0 mpld3-0.5.10 mypy-extensions-1.0.0 netwulf-0.1.5 ninja-1.11.1.1 nltk-3.9.1 normality-2.5.0 numerize-0.12 onnxruntime-1.19.2 opencensus-0.11.4 opencensus-context-0.1.3 packageurl-python-0.15.6 packvers-21.5 pandas-2.2.2 parameter-expansion-patched-0.3.1 parameterized-0.9.0 pdfminer.six-20240706 pefile-2024.8.26 phonenumbers-8.13.46 pip-requirements-parser-32.0.1 pkginfo2-30.0.0 plugincode-32.0.0 ply-3.11 pptree-3.1 presidio-analyzer-2.2.355 presidio-anonymizer-2.2.355 publicsuffix2-2.20191221 py-1.11.0 py-spy-0.3.14 pyahocorasick-2.1.0 pyarrow-16.1.0 pybind11-2.13.6 pyclipper-1.3.0.post5 pycodestyle-2.12.1 pycryptodome-3.20.0 pydantic-settings-2.5.2 pygmars-0.9.0 pylint-3.3.1 pymaven-patch-0.3.2 pypdfium2-4.30.0 pyproject-toml-0.0.10 python-bidi-0.6.0 python-dotenv-1.0.1 pytorch-revgrad-0.2.0 ray-2.24.0 rdflib-7.0.0 requests-file-2.1.0 rtree-1.3.0 s3transfer-0.10.2 saneyaml-0.6.1 scancode-toolkit-32.1.0 scipy-1.14.1 segtok-1.5.11 semantic-version-2.10.0 semver-3.0.2 sentence-transformers-3.0.1 simplejson-3.19.3 smmap-5.0.1 spdx-tools-0.8.2 sqlitedict-2.1.0 starlette-0.38.6 tenacity-8.5.0 textual-0.81.0 tiktoken-0.7.0 tldextract-5.1.2 tokenizers-0.15.2 tomlkit-0.13.2 tqdm-4.66.3 transformer-smaller-training-vocab-0.4.0 transformers-4.38.2 typecode-30.0.2 typecode-libmagic-5.39.210531 typing-inspect-0.9.0 uritools-4.0.3 urllib3-1.26.20 urlpy-0.5 virtualenv-20.26.5 wikipedia-api-0.7.1 xmltodict-0.13.0 xxhash-3.4.1

# %% [markdown]
# ### 2.4 - Restart Runtime
#
# After installing dependencies, be sure <font color="red">restart runtime</font>, so libraries will be loaded
#
# You do this by going to **`Runtime --> Restart Session`**
#
# Then you can continue to the next step (no need to re-run the notebook)

# %% [markdown]
# ## Step-2: Configuration

# %% [markdown]
# ### 2.1 - Basic Config

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
   print("Running in Colab")
   RUNNING_IN_COLAB = True
else:
   print("NOT in Colab")
   RUNNING_IN_COLAB = False
# Out:
# Running in Colab

# %%
import os

## Configuration
class MyConfig:
    pass

MY_CONFIG = MyConfig ()

MY_CONFIG.INPUT_DATA_DIR = 'data/solar-system'
MY_CONFIG.OUTPUT_FOLDER = "output"
MY_CONFIG.OUTPUT_FOLDER_FINAL = os.path.join(MY_CONFIG.OUTPUT_FOLDER , "output_final")

## Embedding model
MY_CONFIG.EMBEDDING_MODEL = 'sentence-transformers/all-MiniLM-L6-v2'

## RAY CONFIGURATION
### For local runs, we can use more parallelism
### For google colab, be conservative

if RUNNING_IN_COLAB:
  MY_CONFIG.RAY_RUNTIME_WORKERS = 2
  MY_CONFIG.RAY_NUM_CPUS =  0.3
  MY_CONFIG.RAY_MEMORY_GB = 2  # GB
else:  # local run
  num_cpus_available =  os.cpu_count()
  # print (num_cpus_available)
  MY_CONFIG.RAY_NUM_CPUS =  1
  MY_CONFIG.RAY_MEMORY_GB = 2  # GB
  # MY_CONFIG.RAY_RUNTIME_WORKERS = num_cpus_available // 3
  MY_CONFIG.RAY_RUNTIME_WORKERS = 2

print ('MY_CONFIG.RAY_RUNTIME_WORKERS:', MY_CONFIG.RAY_RUNTIME_WORKERS)
print ('MY_CONFIG.RAY_NUM_CPUS:', MY_CONFIG.RAY_NUM_CPUS)
print ('MY_CONFIG.RAY_MEMORY_GB:', MY_CONFIG.RAY_MEMORY_GB)
# Out:
# MY_CONFIG.RAY_RUNTIME_WORKERS: 2
# MY_CONFIG.RAY_NUM_CPUS: 0.3
# MY_CONFIG.RAY_MEMORY_GB: 2

# %%
## Add parent dir to path
import os,sys

this_dir = os.path.abspath('')
parent_dir = os.path.dirname(this_dir)
sys.path.append (os.path.abspath (parent_dir))

# %% [markdown]
# ### 2.2 - Setup input/outpur directories

# %%
import os, sys
import shutil

if not os.path.exists(MY_CONFIG.INPUT_DATA_DIR ):
    raise Exception (f"❌ Input folder MY_CONFIG.INPUT_DATA_DIR = '{MY_CONFIG.INPUT_DATA_DIR}' not found")

output_parquet_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '01_parquet_out')
output_chunk_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '02_chunk_out')
output_docid_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '03_docid_out')
output_exact_dedupe_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '04_exact_dedupe_out')
output_fuzzy_dedupe_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '05_fuzzy_dedupe_out')
output_embeddings_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '06_embeddings_out')

## clear output folder
shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER, ignore_errors=True)
shutil.os.makedirs(MY_CONFIG.OUTPUT_FOLDER, exist_ok=True)

print ("✅ Cleared output directory")
# Out:
# ✅ Cleared output directory

# %% [markdown]
# ## Step-3: pdf2parquet -  Convert data from PDF to Parquet
#
# This step is reading the input folder containing all PDF files and ingest them in a parquet table using the [Docling package](https://github.com/DS4SD/docling).
# The documents are converted into a JSON format which allows to easily chunk it in the later steps.

# %% [markdown]
# ### 3.1 - Set Input/output Folder

# %%
STAGE = 1

input_folder = MY_CONFIG.INPUT_DATA_DIR
output_folder =  output_parquet_dir

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-1: Processing input='data/solar-system' --> output='output/01_parquet_out'

# %% [markdown]
# ### 3.2 - Execute

# %%
# %%time

import ast
import os
import sys

from pdf2parquet_transform import (
    pdf2parquet_contents_type_cli_param,
    pdf2parquet_contents_types,
)
from data_processing_ray.runtime.ray import RayTransformLauncher
from pdf2parquet_transform_python import Pdf2ParquetPythonTransformConfiguration
from pdf2parquet_transform_ray import Pdf2ParquetRayTransformConfiguration

from data_processing.utils import GB, ParamsUtils


# create parameters
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS, "memory": MY_CONFIG.RAY_MEMORY_GB * GB}
ingest_config = {
    pdf2parquet_contents_type_cli_param: pdf2parquet_contents_types.JSON,
}

params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    "data_files_to_use": ast.literal_eval("['.pdf']"),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
}


sys.argv = ParamsUtils.dict_to_req(d=(params | ingest_config))
# create launcher
launcher = RayTransformLauncher(Pdf2ParquetRayTransformConfiguration())
# launcher = PythonTransformLauncher(Pdf2ParquetPythonTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 07:26:32 INFO - pdf2parquet parameters are : {'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': True, 'double_precision': 8}
# INFO:pdf2parquet_transform:pdf2parquet parameters are : {'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': True, 'double_precision': 8}
# 07:26:32 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:26:32 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:26:32 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'memory': 2147483648, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'memory': 2147483648, 'max_restarts': -1}
# 07:26:32 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:26:32 INFO - job details {'job category': 'preprocessing', 'job name': 'pdf2parquet', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'pdf2parquet', 'job type': 'ray', 'job id': 'job_id'}
# 07:26:32 INFO - data factory data_ is using local data access: input_folder - data/solar-system output_folder - output/01_parquet_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - data/solar-system output_folder - output/01_parquet_out
# 07:26:32 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:26:32 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# 07:26:32 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:26:36,497	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=4697) 07:26:45 INFO - orchestrator started at 2024-09-26 07:26:45
# (orchestrate pid=4697) 07:26:45 INFO - Number of files is 2, source profile {'max_file_size': 0.055823326110839844, 'min_file_size': 0.0551910400390625, 'total_file_size': 0.11101436614990234}
# (orchestrate pid=4697) 07:26:45 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.428378297016025, 'object_store': 3.7141891475766897}
# (orchestrate pid=4697) 07:26:45 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'memory': 2147483648, 'max_restarts': -1} each
# (orchestrate pid=4697) 07:26:45 INFO - Completed 0 files (0.0%)  in 0.0 min. Waiting for completion
# (RayTransformFileProcessor pid=4846) 07:26:56 INFO - Initializing models
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 4082.71it/s]
# (RayTransformFileProcessor pid=4846) Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# (orchestrate pid=4697) 07:27:16 INFO - Completed processing 2 files in 0.515 min
# (orchestrate pid=4697) 07:27:16 INFO - done flushing in 0.006 sec
# (RayTransformFileProcessor pid=4886) 07:26:57 INFO - Initializing models
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 63657.23it/s]
# (RayTransformFileProcessor pid=4886) Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 07:27:26 INFO - Completed execution in 0.893 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.893 min, execution result 0
# ✅ Stage:1 completed successfully
# CPU times: user 579 ms, sys: 187 ms, total: 766 ms
# Wall time: 55.3 s

# %% [markdown]
# ### 3.3 - Inspect Generated output
#
# Here we should see one entry per input file processed.

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Output dimensions (rows x columns)= ", output_df.shape)

output_df.head(5)

## To display certain columns
#parquet_df[['column1', 'column2', 'column3']].head(5)
# Out:
# Output dimensions (rows x columns)=  (2, 12)
#     filename                                           contents  num_pages  \
# 0  earth.pdf  {"_name":"","type":"pdf-document","description...          1
# 1   mars.pdf  {"_name":"","type":"pdf-document","description...          1
#
#    num_tables  num_doc_elements                           document_id  ext  \
# 0           0                11  882b0ae9-00ff-4971-8462-c4e35bac569c  pdf
# 1           0                11  2e42c0c7-69f7-4582-8aef-8dd493cfda1a  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.355166          9.173448        mars.pdf

# %% [markdown]
# ### 3.4 - Understand the output
#
# Here are some interesting attributes to note:
#
# - **filename** : original filename
# - **contents** : text
# - **document_id**: unique id (UUID) assignd to this document
# - **hash** : hash of document
# - **pdf_convert_time** : time to convert this pdf in seconds
#
# Let's inspect the **contents** column.  See how the text is being divided up!

# %%
import pprint
import json

pprint.pprint (json.loads(output_df.iloc[0, ]['contents']))
# json.loads(output_df.iloc[0, ]['contents'])
# Out:
# {'_name': '',
#  'description': {'logs': []},
#  'equations': [],
#  'figures': [],
#  'file-info': {'#-pages': 1,
#                'document-hash': '7401ae81637dbb89e7040dcd5945bbfb75ff8648bb761c69f8a1595e86538748',
#                'filename': 'earth.pdf',
#                'page-hashes': [{'hash': 'ca802e4bd5a3301792808caea2a47db51f0520888875b77fc230c99ee851c19b',
#                                 'model': 'default',
#                                 'page': 1}]},
#  'footnotes': [],
#  'main-text': [{'name': 'Section-header',
#                 'prov': [{'bbox': [133.30961609,
#                                    654.45184326,
#                                    174.04208374,
#                                    667.93347168],
#                           'page': 1,
#                           'span': [0, 5]}],
#                 'text': 'Earth',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.12528992,
#                                    630.69073486,
#                                    210.66503906,
#                                    642.27935791],
#                           'page': 1,
#                           'span': [0, 12]}],
#                 'text': 'Solar System',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [132.87112427,
#                                    588.96014404,
#                                    479.40917969,
#                                    623.04595947],
#                           'page': 1,
#                           'span': [0, 205]}],
#                 'text': 'Our solar system is a vast and fascinating expanse, '
#                         'comprising eight planets, five dwarf planets, '
#                         'numerous moons, asteroids, comets, and other '
#                         'celestial bodies. At its center lies the star we call '
#                         'the Sun.',
#                 'type': 'paragraph'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [133.20942688,
#                                    570.81555176,
#                                    375.57919312,
#                                    581.08459473],
#                           'page': 1,
#                           'span': [0, 54]}],
#                 'text': 'For more details about our Solar system see Chapter '
#                         '1.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.15542603,
#                                    542.98168945,
#                                    167.32983398,
#                                    554.36669922],
#                           'page': 1,
#                           'span': [0, 5]}],
#                 'text': 'Earth',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [132.91053772,
#                                    512.46295166,
#                                    477.84887695,
#                                    534.48431396],
#                           'page': 1,
#                           'span': [0, 107]}],
#                 'text': "Earth is the third planet from the Sun. It's our home "
#                         'planet. Earth is the only place we know of with life.',
#                 'type': 'paragraph'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [133.30151367,
#                                    494.86206055,
#                                    240.17156982,
#                                    505.07229614],
#                           'page': 1,
#                           'span': [0, 24]}],
#                 'text': 'Basic facts about Earth:',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    464.97409058,
#                                    477.47979736,
#                                    487.02810669],
#                           'page': 1,
#                           'span': [0, 79]}],
#                 'text': '· Distance from the Sun: Average of 149.6 million '
#                         'kilometers (93 million miles)',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    452.86901855,
#                                    317.90722656,
#                                    463.24041748],
#                           'page': 1,
#                           'span': [0, 37]}],
#                 'text': '· Rotation Period: 24 hours (one day)',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    440.71496582,
#                                    396.66357422,
#                                    451.19915771],
#                           'page': 1,
#                           'span': [0, 52]}],
#                 'text': '· Moons: One moon, called Luna or simply "the Moon".',
#                 'type': 'paragraph'},
#                {'name': 'Page-footer',
#                 'prov': [{'bbox': [303.13299561,
#                                    87.20314026,
#                                    308.11428833,
#                                    96.53633118],
#                           'page': 1,
#                           'span': [0, 1]}],
#                 'text': '1',
#                 'type': 'page-footer'}],
#  'page-dimensions': [{'height': 792.0, 'page': 1, 'width': 612.0}],
#  'page-footers': [],
#  'page-headers': [],
#  'tables': [],
#  'type': 'pdf-document'}

# %%
pprint.pprint (json.loads(output_df.iloc[1, ]['contents']))
# Out:
# {'_name': '',
#  'description': {'logs': []},
#  'equations': [],
#  'figures': [],
#  'file-info': {'#-pages': 1,
#                'document-hash': '1a83f43f3a202e3f203c1263e36961ecc45d401aad488f638fc5559a584333b2',
#                'filename': 'mars.pdf',
#                'page-hashes': [{'hash': '551fe7a9bde2a9302f150c0a79a13fcc0868fcf73ac6afb80be645c1174734a0',
#                                 'model': 'default',
#                                 'page': 1}]},
#  'footnotes': [],
#  'main-text': [{'name': 'Section-header',
#                 'prov': [{'bbox': [133.35137939,
#                                    654.45184326,
#                                    169.88169861,
#                                    667.98492432],
#                           'page': 1,
#                           'span': [0, 4]}],
#                 'text': 'Mars',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.09541321,
#                                    630.68127441,
#                                    210.66503906,
#                                    642.34405518],
#                           'page': 1,
#                           'span': [0, 12]}],
#                 'text': 'Solar System',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [132.84518433,
#                                    588.96014404,
#                                    479.40917969,
#                                    623.02520752],
#                           'page': 1,
#                           'span': [0, 205]}],
#                 'text': 'Our solar system is a vast and fascinating expanse, '
#                         'comprising eight planets, five dwarf planets, '
#                         'numerous moons, asteroids, comets, and other '
#                         'celestial bodies. At its center lies the star we call '
#                         'the Sun.',
#                 'type': 'paragraph'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [133.18510437,
#                                    570.83258057,
#                                    374.99838257,
#                                    581.07043457],
#                           'page': 1,
#                           'span': [0, 54]}],
#                 'text': 'For more details about the Solar system see Chapter '
#                         '1.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.22866821,
#                                    542.98168945,
#                                    163.86282349,
#                                    554.45288086],
#                           'page': 1,
#                           'span': [0, 4]}],
#                 'text': 'Mars',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [132.87440491,
#                                    500.84011841,
#                                    477.48345947,
#                                    534.55810547],
#                           'page': 1,
#                           'span': [0, 196]}],
#                 'text': 'Mars, the fourth planet from the Sun, is a cold, '
#                         'desert world with a thin atmosphere composed '
#                         'primarily of carbon dioxide. Its reddish hue comes '
#                         'from iron oxide, or rust, prevalent on its surface.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.2026062,
#                                    482.90710449,
#                                    237.04431152,
#                                    493.07443237],
#                           'page': 1,
#                           'span': [0, 23]}],
#                 'text': 'Basic facts about Mars:',
#                 'type': 'subtitle-level-1'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    453.019104,
#                                    477.48171997,
#                                    474.9703064],
#                           'page': 1,
#                           'span': [0, 78]}],
#                 'text': '· Distance from the Sun: Average of 228 million '
#                         'kilometers (142 million miles)',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    440.79351807,
#                                    431.73287964,
#                                    451.2142334],
#                           'page': 1,
#                           'span': [0, 64]}],
#                 'text': '· Rotation Period: 24.6 hours (one Martian day - '
#                         'called a "sol")',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [145.94500732,
#                                    429.10913086,
#                                    365.9559021,
#                                    438.83737183],
#                           'page': 1,
#                           'span': [0, 44]}],
#                 'text': '· Moons: Two small moons, Phobos and Deimos.',
#                 'type': 'paragraph'},
#                {'name': 'Page-footer',
#                 'prov': [{'bbox': [303.13299561,
#                                    87.20314026,
#                                    308.11428833,
#                                    96.51646423],
#                           'page': 1,
#                           'span': [0, 1]}],
#                 'text': '1',
#                 'type': 'page-footer'}],
#  'page-dimensions': [{'height': 792.0, 'page': 1, 'width': 612.0}],
#  'page-footers': [],
#  'page-headers': [],
#  'tables': [],
#  'type': 'pdf-document'}

# %% [markdown]
# ##  Step-4: Doc chunks
#
# In the previous step, we have extracted text from oru PDFs.  But we have the content of entire file as 'one row' in our parquet output.
#
# In this step, we are going to split the documents in chunks, according to their layout segmentation.
#
# This transform uses [Quackling](https://github.com/DS4SD/quackling) `HierarchicalChunker`
# to chunk according to the document layout segmentation, i.e. respecting the original document components as paragraphs, tables, enumerations, etc.
# It relies on documents converted with the Docling library in the [pdf2parquet transform](https://github.com/IBM/data-prep-kit/blob/dev/transforms/language/pdf2parquet/python/README.md) using the option `contents_type: "application/json"`,
# which provides the required JSON structure.

# %% [markdown]
# ### 4.1 - Set Input/output Folder

# %%
STAGE = 2

input_folder = output_parquet_dir # previous output folder is the input folder for the current stage
output_folder =  output_chunk_dir

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-2: Processing input='output/01_parquet_out' --> output='output/02_chunk_out'

# %% [markdown]
# ### 4.2 - Execute

# %%
# %%time

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_chunk_transform_ray import DocChunkRayTransformConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc_chunk arguments
    # ...
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(DocChunkRayTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 07:27:31 INFO - doc_chunk parameters are : {'chunking_type': <chunking_types.DL_JSON: 'dl_json'>, 'content_column_name': 'contents', 'doc_id_column_name': 'document_id', 'dl_min_chunk_len': None, 'output_chunk_column_name': 'contents', 'output_source_doc_id_column_name': 'source_document_id', 'output_jsonpath_column_name': 'doc_jsonpath', 'output_pageno_column_name': 'page_number', 'output_bbox_column_name': 'bbox'}
# INFO:doc_chunk_transformcfg:doc_chunk parameters are : {'chunking_type': <chunking_types.DL_JSON: 'dl_json'>, 'content_column_name': 'contents', 'doc_id_column_name': 'document_id', 'dl_min_chunk_len': None, 'output_chunk_column_name': 'contents', 'output_source_doc_id_column_name': 'source_document_id', 'output_jsonpath_column_name': 'doc_jsonpath', 'output_pageno_column_name': 'page_number', 'output_bbox_column_name': 'bbox'}
# 07:27:31 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:27:31 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:27:31 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# 07:27:31 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:27:31 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_chunk', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'doc_chunk', 'job type': 'ray', 'job id': 'job_id'}
# 07:27:31 INFO - data factory data_ is using local data access: input_folder - output/01_parquet_out output_folder - output/02_chunk_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - output/01_parquet_out output_folder - output/02_chunk_out
# 07:27:31 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:27:31 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 07:27:31 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:27:35,368	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=5260) 07:27:42 INFO - orchestrator started at 2024-09-26 07:27:42
# (orchestrate pid=5260) 07:27:42 INFO - Number of files is 2, source profile {'max_file_size': 0.02239513397216797, 'min_file_size': 0.02167987823486328, 'total_file_size': 0.04407501220703125}
# (orchestrate pid=5260) 07:27:42 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.427835847251117, 'object_store': 3.7139179222285748}
# (orchestrate pid=5260) 07:27:42 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'max_restarts': -1} each
# (orchestrate pid=5260) 07:27:42 INFO - Completed 0 files (0.0%)  in 0.002 min. Waiting for completion
# (orchestrate pid=5260) 07:27:50 INFO - Completed processing 2 files in 0.126 min
# (orchestrate pid=5260) 07:27:50 INFO - done flushing in 0.009 sec
# 07:28:00 INFO - Completed execution in 0.476 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.476 min, execution result 0
# ✅ Stage:2 completed successfully
# CPU times: user 2.55 s, sys: 442 ms, total: 2.99 s
# Wall time: 33.8 s

# %% [markdown]
# ### 4.3 - Inspect Generated output
#
# We would see documents are split into many chunks

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print (f"Files processed : {input_df.shape[0]:,}")
print (f"Chunks created : {output_df.shape[0]:,}")

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Files processed : 2
# Chunks created : 8
# Input data dimensions (rows x columns)=  (2, 12)
# Output data dimensions (rows x columns)=  (8, 16)
#     filename  num_pages  num_tables  num_doc_elements  ext  \
# 0  earth.pdf          1           0                11  pdf
# 1  earth.pdf          1           0                11  pdf
# 2  earth.pdf          1           0                11  pdf
# 3  earth.pdf          1           0                11  pdf
# 4   mars.pdf          1           0                11  pdf
# 5   mars.pdf          1           0                11  pdf
# 6   mars.pdf          1           0                11  pdf
# 7   mars.pdf          1           0                11  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 2  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 3  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 4  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 5  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 6  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 7  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 2  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 3  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 4  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 5  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 6  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 7  2024-09-26T07:27:16.355166          9.173448        mars.pdf
#
#                      source_document_id  \
# 0  882b0ae9-00ff-4971-8462-c4e35bac569c
# 1  882b0ae9-00ff-4971-8462-c4e35bac569c
# 2  882b0ae9-00ff-4971-8462-c4e35bac569c
# 3  882b0ae9-00ff-4971-8462-c4e35bac569c
# 4  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 5  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 6  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 7  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about our Solar...  $.main-text[3]
# 2  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 3  Earth\nBasic facts about Earth:\n· Distance fr...  $.main-text[6]
# 4  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 5  Solar System\nFor more details about the Solar...  $.main-text[3]
# 6  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 7  Basic facts about Mars:\n· Distance from the S...  $.main-text[6]
#
#    page_number                                               bbox  \
# 0            1  [132.87112427, 588.96014404, 479.40917969, 623...
# 1            1  [133.20942688, 570.81555176, 375.57919312, 581...
# 2            1  [132.91053772, 512.46295166, 477.84887695, 534...
# 3            1  [133.30151367, 494.86206055, 240.17156982, 505...
# 4            1  [132.84518433, 588.96014404, 479.40917969, 623...
# 5            1  [133.18510437, 570.83258057, 374.99838257, 581...
# 6            1  [132.87440491, 500.84011841, 477.48345947, 534...
# 7            1  [133.2026062, 482.90710449, 237.04431152, 493....
#
#                                          document_id
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...
# 1  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...
# 2  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...
# 3  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...
# 4  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...
# 5  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...
# 6  a31663e06fac41470ecc459f5a58658a3f9997d7801053...
# 7  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...

# %% [markdown]
# ### 4.4 - Understanding the Output
#
# Here we see 2 PDF files are split into 6 chunks.  Basically we see the documents are being split along 'natural boundaris' - paragraphs and bullet points
#
# See how **document_id** is carried throughout.  This helps us identify original documents.
#
# Also note **contents** is now plain text (not JSON as before)

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0  earth.pdf  Solar System\nOur solar system is a vast and f...
# 1  earth.pdf  Solar System\nFor more details about our Solar...
# 2  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 3  earth.pdf  Earth\nBasic facts about Earth:\n· Distance fr...
# 4   mars.pdf  Solar System\nOur solar system is a vast and f...
# 5   mars.pdf  Solar System\nFor more details about the Solar...
# 6   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 7   mars.pdf  Basic facts about Mars:\n· Distance from the S...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== earth.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about our Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 3------
# Earth
# Basic facts about Earth:
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# · Moons: One moon, called Luna or simply "the Moon".
# -------
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 3------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------

# %% [markdown]
# ## Step-5:  DOC ID generation
#
# This transform annotates documents with document "ids". It supports the following transformations of the original data:
#
#  - Adding document hash: this enables the addition of a document hash-based id to the data. The hash is calculated with `hashlib.sha256(doc.encode("utf-8")).hexdigest()`. To enable this annotation, set **hash_column** to the name of the column, where you want to store it.
#  - Adding integer document id: this allows the addition of an integer document id to the data that is unique across all rows in all tables provided to the transform() method. To enable this annotation, set **int_id_column** to the name of the column, where you want to store it.
#
# **This is a pre-requisite for fuzzy dedup** in the pipeline.

# %% [markdown]
# ### 5.1 - Set Input/output Folder

# %%
# Input for this stage is the output of exact dedeup component
# output of this component makes it possible for fdedup component to run on data.

STAGE  = 3

input_folder = output_chunk_dir
output_folder =  output_docid_dir

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-3: Processing input='output/02_chunk_out' --> output='output/03_docid_out'

# %% [markdown]
# ### 5.2 - Execute

# %%
# %%time

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_id_transform_ray import DocIDRayTransformRuntimeConfiguration

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc id configuration
    "doc_id_doc_column": "contents",
    "doc_id_hash_column": "chunk_hash",
    "doc_id_int_column": "chunk_id",
}
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(DocIDRayTransformRuntimeConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 07:28:02 INFO - Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'chunk_hash', 'int_column': 'chunk_id', 'start_id': 0}
# INFO:doc_id_transform_base:Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'chunk_hash', 'int_column': 'chunk_id', 'start_id': 0}
# 07:28:02 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:28:02 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:28:02 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# 07:28:02 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:28:02 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_id', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'doc_id', 'job type': 'ray', 'job id': 'job_id'}
# 07:28:02 INFO - data factory data_ is using local data access: input_folder - output/02_chunk_out output_folder - output/03_docid_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - output/02_chunk_out output_folder - output/03_docid_out
# 07:28:02 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:28:02 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 07:28:02 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:28:05,960	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=5701) 07:28:09 INFO - orchestrator started at 2024-09-26 07:28:09
# (orchestrate pid=5701) 07:28:09 INFO - Number of files is 2, source profile {'max_file_size': 0.008975982666015625, 'min_file_size': 0.008897781372070312, 'total_file_size': 0.017873764038085938}
# (orchestrate pid=5701) 07:28:09 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.428096771240234, 'object_store': 3.714048385620117}
# (orchestrate pid=5701) 07:28:09 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'max_restarts': -1} each
# (orchestrate pid=5701) 07:28:10 INFO - Completed 0 files (0.0%)  in 0.002 min. Waiting for completion
# (orchestrate pid=5701) 07:28:15 INFO - Completed processing 2 files in 0.094 min
# (orchestrate pid=5701) 07:28:15 INFO - done flushing in 0.005 sec
# 07:28:25 INFO - Completed execution in 0.395 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.395 min, execution result 0
# ✅ Stage:3 completed successfully
# CPU times: user 346 ms, sys: 178 ms, total: 525 ms
# Wall time: 25.2 s

# %% [markdown]
# ### 5.3 - Inspect Generated output
#
# You will notice we have two extra columns
#
# - **hash_column**
# - **int_id_column**
#
# But still the same number or rows as before

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (8, 16)
# Output data dimensions (rows x columns)=  (8, 18)
#     filename  num_pages  num_tables  num_doc_elements  ext  \
# 0  earth.pdf          1           0                11  pdf
# 1  earth.pdf          1           0                11  pdf
# 2  earth.pdf          1           0                11  pdf
# 3  earth.pdf          1           0                11  pdf
# 4   mars.pdf          1           0                11  pdf
# 5   mars.pdf          1           0                11  pdf
# 6   mars.pdf          1           0                11  pdf
# 7   mars.pdf          1           0                11  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 2  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 3  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 4  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 5  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 6  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 7  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 2  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 3  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 4  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 5  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 6  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 7  2024-09-26T07:27:16.355166          9.173448        mars.pdf
#
#                      source_document_id  \
# 0  882b0ae9-00ff-4971-8462-c4e35bac569c
# 1  882b0ae9-00ff-4971-8462-c4e35bac569c
# 2  882b0ae9-00ff-4971-8462-c4e35bac569c
# 3  882b0ae9-00ff-4971-8462-c4e35bac569c
# 4  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 5  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 6  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 7  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about our Solar...  $.main-text[3]
# 2  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 3  Earth\nBasic facts about Earth:\n· Distance fr...  $.main-text[6]
# 4  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 5  Solar System\nFor more details about the Solar...  $.main-text[3]
# 6  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 7  Basic facts about Mars:\n· Distance from the S...  $.main-text[6]
#
#    page_number                                               bbox  \
# 0            1  [132.87112427, 588.96014404, 479.40917969, 623...
# 1            1  [133.20942688, 570.81555176, 375.57919312, 581...
# 2            1  [132.91053772, 512.46295166, 477.84887695, 534...
# 3            1  [133.30151367, 494.86206055, 240.17156982, 505...
# 4            1  [132.84518433, 588.96014404, 479.40917969, 623...
# 5            1  [133.18510437, 570.83258057, 374.99838257, 581...
# 6            1  [132.87440491, 500.84011841, 477.48345947, 534...
# 7            1  [133.2026062, 482.90710449, 237.04431152, 493....
#
#                                          document_id  \
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...
# 1  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...
# 2  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...
# 3  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...
# 4  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...
# 5  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...
# 6  a31663e06fac41470ecc459f5a58658a3f9997d7801053...
# 7  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...
#
#                                           chunk_hash  chunk_id
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...         4
# 1  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...         5
# 2  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...         6
# 3  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...         7
# 4  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...         0
# 5  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...         1
# 6  a31663e06fac41470ecc459f5a58658a3f9997d7801053...         2
# 7  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...         3

# %% [markdown]
# ## Step-6: Exact Dedup

# %% [markdown]
# ### 6.1 - Set Input/output Folder

# %%
STAGE  = 4

input_folder = output_docid_dir # previous output folder is the input folder for the current stage
output_folder =  output_exact_dedupe_dir

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-4: Processing input='output/03_docid_out' --> output='output/04_exact_dedupe_out'

# %% [markdown]
# ### 6.2 - Execute

# %%
# %%time

from data_processing_ray.runtime.ray import RayTransformLauncher
from ededup_transform_ray import EdedupRayTransformRuntimeConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # ededup parameters
    "ededup_hash_cpu": 0.5,
    "ededup_num_hashes": 2,
    "ededup_doc_column": "contents",
    "ededup_doc_id_column": "chunk_hash",
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(EdedupRayTransformRuntimeConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 07:28:27 INFO - exact dedup params are {'doc_column': 'contents', 'doc_id_column': 'chunk_hash', 'use_snapshot': False, 'snapshot_directory': None, 'hash_cpu': 0.5, 'num_hashes': 2}
# INFO:ededup_transform_base:exact dedup params are {'doc_column': 'contents', 'doc_id_column': 'chunk_hash', 'use_snapshot': False, 'snapshot_directory': None, 'hash_cpu': 0.5, 'num_hashes': 2}
# 07:28:27 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:28:27 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:28:27 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# 07:28:27 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:28:27 INFO - job details {'job category': 'preprocessing', 'job name': 'ededup', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'ededup', 'job type': 'ray', 'job id': 'job_id'}
# 07:28:27 INFO - data factory data_ is using local data access: input_folder - output/03_docid_out output_folder - output/04_exact_dedupe_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - output/03_docid_out output_folder - output/04_exact_dedupe_out
# 07:28:27 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:28:27 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 07:28:27 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:28:31,406	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=6145) 07:28:34 INFO - orchestrator started at 2024-09-26 07:28:34
# (orchestrate pid=6145) 07:28:34 INFO - Number of files is 2, source profile {'max_file_size': 0.010180473327636719, 'min_file_size': 0.010101318359375, 'total_file_size': 0.02028179168701172}
# (orchestrate pid=6145) 07:28:34 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.428108215332031, 'object_store': 3.7140541076660156}
# (orchestrate pid=6145) 07:28:34 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'max_restarts': -1} each
# (orchestrate pid=6145) 07:28:34 INFO - Completed 0 files (0.0%)  in 0.001 min. Waiting for completion
# (orchestrate pid=6145) 07:28:40 INFO - Completed processing 2 files in 0.095 min
# (orchestrate pid=6145) 07:28:40 INFO - done flushing in 0.009 sec
# 07:28:50 INFO - Completed execution in 0.379 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.379 min, execution result 0
# ✅ Stage:4 completed successfully
# CPU times: user 330 ms, sys: 175 ms, total: 505 ms
# Wall time: 24.4 s

# %% [markdown]
# ### 6.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input chunks before exact dedupe : {input_df.shape[0]:,}")
print (f"Output chunks after exact dedupe : {output_df.shape[0]:,}")
print ("Duplicate chunks removed :  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (8, 18)
# Output data dimensions (rows x columns)=  (7, 19)
# Input chunks before exact dedupe : 8
# Output chunks after exact dedupe : 7
# Duplicate chunks removed :   1
#     filename  num_pages  num_tables  num_doc_elements  ext  \
# 0  earth.pdf          1           0                11  pdf
# 1  earth.pdf          1           0                11  pdf
# 2  earth.pdf          1           0                11  pdf
# 3  earth.pdf          1           0                11  pdf
# 4   mars.pdf          1           0                11  pdf
# 5   mars.pdf          1           0                11  pdf
# 6   mars.pdf          1           0                11  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 2  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 3  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 4  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 5  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 6  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 2  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 3  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 4  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 5  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 6  2024-09-26T07:27:16.355166          9.173448        mars.pdf
#
#                      source_document_id  \
# 0  882b0ae9-00ff-4971-8462-c4e35bac569c
# 1  882b0ae9-00ff-4971-8462-c4e35bac569c
# 2  882b0ae9-00ff-4971-8462-c4e35bac569c
# 3  882b0ae9-00ff-4971-8462-c4e35bac569c
# 4  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 5  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 6  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about our Solar...  $.main-text[3]
# 2  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 3  Earth\nBasic facts about Earth:\n· Distance fr...  $.main-text[6]
# 4  Solar System\nFor more details about the Solar...  $.main-text[3]
# 5  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 6  Basic facts about Mars:\n· Distance from the S...  $.main-text[6]
#
#    page_number                                               bbox  \
# 0            1  [132.87112427, 588.96014404, 479.40917969, 623...
# 1            1  [133.20942688, 570.81555176, 375.57919312, 581...
# 2            1  [132.91053772, 512.46295166, 477.84887695, 534...
# 3            1  [133.30151367, 494.86206055, 240.17156982, 505...
# 4            1  [133.18510437, 570.83258057, 374.99838257, 581...
# 5            1  [132.87440491, 500.84011841, 477.48345947, 534...
# 6            1  [133.2026062, 482.90710449, 237.04431152, 493....
#
#                                          document_id  \
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...
# 1  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...
# 2  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...
# 3  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...
# 4  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...
# 5  a31663e06fac41470ecc459f5a58658a3f9997d7801053...
# 6  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...
#
#                                           chunk_hash  chunk_id  \
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...         4
# 1  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...         5
# 2  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...         6
# 3  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...         7
# 4  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...         1
# 5  a31663e06fac41470ecc459f5a58658a3f9997d7801053...         2
# 6  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...         3
#
#                                              removed
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf567...
# 5                                                 []
# 6                                                 []

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0  earth.pdf  Solar System\nOur solar system is a vast and f...
# 1  earth.pdf  Solar System\nFor more details about our Solar...
# 2  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 3  earth.pdf  Earth\nBasic facts about Earth:\n· Distance fr...
# 4   mars.pdf  Solar System\nFor more details about the Solar...
# 5   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 6   mars.pdf  Basic facts about Mars:\n· Distance from the S...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== earth.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about our Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 3------
# Earth
# Basic facts about Earth:
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# · Moons: One moon, called Luna or simply "the Moon".
# -------
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 1------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 2------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------

# %% [markdown]
# ### 6.4 - Understanding the output
#
# Remember we had 8 chunks initially.  Now we have 7!  One duplicate chunk is removed.
#
# If you look at the PDF, the following common paragraph in `earth.pdf` and `mars.pdf`  is removed from one of the documents!  Pretty neat, eh!
#
# ```text
# ## Solar System
#
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# ```

# %% [markdown]
# ## Step-7: Fuzzy Dedup
#
# Post exact deduplication, fuzzy deduplication is applied with the goal of removing code files that may have **slight variations** and thereby unbiasing
# the data further.
#
# Small variations are quite commonly seen in code data in the form of variations in the values of variables, addittion of logging statements etc.

# %% [markdown]
# ### 7.1 - Set Input/output Folder

# %%
## Input to this component is the output of doc_id generator component.

STAGE  = 5

input_folder = output_docid_dir # previous output folder is the input folder for the current stage
output_folder =  output_fuzzy_dedupe_dir

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-5: Processing input='output/03_docid_out' --> output='output/05_fuzzy_dedupe_out'

# %% [markdown]
# ### 7.2 - Execute

# %%
# %%time

import os
import sys

from data_processing.utils import ParamsUtils
from fdedup_transform_ray import FdedupRayTransformConfiguration
from data_processing_ray.runtime.ray import RayTransformLauncher

# create parameters

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
code_location = {"github": "github", "commit_hash": "12345", "path": "path"}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # Orchestration parameters
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # columns used
    "fdedup_doc_column": "contents",
    "fdedup_id_column": "chunk_id",
    "fdedup_cluster_column": "chunk_hash",
    # infrastructure
    "fdedup_bucket_cpu": 0.3,
    "fdedup_doc_cpu": 0.3,
    "fdedup_mhash_cpu": 0.3,
    "fdedup_num_doc_actors": 1,
    "fdedup_num_bucket_actors": 1,
    "fdedup_num_minhash_actors": 1,
    "fdedup_num_preprocessors": 1,
    # fuzzy parameters
    "fdedup_num_permutations": 64,
    "fdedup_threshold": 0.7, # (default 0.8)
    "fdedup_shingles_size": 5,
    "fdedup_delimiters": " "
}

# Pass commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(FdedupRayTransformConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 07:28:52 INFO - fuzzy dedup params are {'doc_column': 'contents', 'id_column': 'chunk_id', 'cluster_column': 'chunk_hash', 'bucket_cpu': 0.3, 'mhash_cpu': 0.3, 'doc_cpu': 0.3, 'num_doc_actors': 1, 'num_minhash_actors': 1, 'num_bucket_actors': 1, 'num_preprocessors': 1, 'num_permutations': 64, 'threshold': 0.7, 'shingles_size': 5, 'delimiters': ' ', 'snapshot_delay': 1, 'use_bucket_snapshot': False, 'use_doc_snapshot': False, 'random_delay_limit': 10, 'worker_options': {'num_cpus': 0.3}}
# INFO:fdedup_transform_ray:fuzzy dedup params are {'doc_column': 'contents', 'id_column': 'chunk_id', 'cluster_column': 'chunk_hash', 'bucket_cpu': 0.3, 'mhash_cpu': 0.3, 'doc_cpu': 0.3, 'num_doc_actors': 1, 'num_minhash_actors': 1, 'num_bucket_actors': 1, 'num_preprocessors': 1, 'num_permutations': 64, 'threshold': 0.7, 'shingles_size': 5, 'delimiters': ' ', 'snapshot_delay': 1, 'use_bucket_snapshot': False, 'use_doc_snapshot': False, 'random_delay_limit': 10, 'worker_options': {'num_cpus': 0.3}}
# 07:28:52 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:28:52 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:28:52 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# 07:28:52 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:28:52 INFO - job details {'job category': 'preprocessing', 'job name': 'fdedup', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'fdedup', 'job type': 'ray', 'job id': 'job_id'}
# 07:28:52 INFO - data factory data_ is using local data access: input_folder - output/03_docid_out output_folder - output/05_fuzzy_dedupe_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - output/03_docid_out output_folder - output/05_fuzzy_dedupe_out
# 07:28:52 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:28:52 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 07:28:52 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:28:56,855	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=6623) 07:28:59 INFO - orchestrator started at 2024-09-26 07:28:59
# (orchestrate pid=6623) 07:28:59 INFO - Number of files is 2, source profile {'max_file_size': 0.010180473327636719, 'min_file_size': 0.010101318359375, 'total_file_size': 0.02028179168701172}
# (orchestrate pid=6623) 07:28:59 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.427794648334384, 'object_store': 3.7138973232358694}
# (orchestrate pid=6623) 07:28:59 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'max_restarts': -1} each
# (orchestrate pid=6623) 07:28:59 INFO - starting run from the beginning
# (orchestrate pid=6623) 07:28:59 INFO - continuing from the very beginning
# (orchestrate pid=6623) 07:28:59 INFO - Fuzzy: num buckets 8, bucket length 8
# (orchestrate pid=6623) 07:28:59 INFO - created 1 bucket actors
# (orchestrate pid=6623) 07:29:00 INFO - created 1 minhash actors
# (orchestrate pid=6623) 07:29:00 INFO - Table preprocessing uses 1 readers
# (orchestrate pid=6623) 07:29:00 INFO - created 1 table processor actors
# (orchestrate pid=6623) 07:29:06 INFO - Completed 1 files in 0.105 min
# (orchestrate pid=6623) 07:29:06 INFO - Completed 1 files (50.0%)  in 0.105 min. Waiting for completion
# (orchestrate pid=6623) 07:29:11 INFO - Completed processing 2 files in 0.189 min
# (orchestrate pid=6623) 07:29:11 INFO - creating minhash snapshots
# (orchestrate pid=6623) 07:29:12 INFO - minhash snapshots created
# (orchestrate pid=6623) 07:29:12 INFO - creating bucket snapshots
# (orchestrate pid=6623) 07:29:13 INFO - bucket snapshots created
# (orchestrate pid=6623) 07:29:13 INFO - created 1 document actors
# (orchestrate pid=6623) 07:29:13 INFO - created 1 bucket processor actors
# (orchestrate pid=6623) 07:29:13 INFO - created bucket processor invoker
# (orchestrate pid=6623) 07:29:13 INFO - added invoker to bucket collectors
# (BucketsHash pid=6736) 07:29:13 INFO - processing buckets 0 long, 53 short
# (BucketsHash pid=6736) 07:29:13 INFO - Done submitting long buckets
# (BucketsHashProcessorInvoker pid=6951) 07:29:16 INFO - Waiting bucket processing completion. Submitted requests 1
# (orchestrate pid=6623) 07:29:16 INFO - Done processing buckets in 0.048 min
# (orchestrate pid=6623) 07:29:16 INFO - creating document snapshots
# (orchestrate pid=6623) 07:29:17 INFO - document snapshots created
# (orchestrate pid=6623) 07:29:17 INFO - Completed 0 files (0.0%)  in 0.0 min. Waiting for completion
# (orchestrate pid=6623) 07:29:27 INFO - Completed processing 2 files in 0.156 min
# (orchestrate pid=6623) 07:29:27 INFO - done flushing in 0.005 sec
# 07:29:37 INFO - Completed execution in 0.753 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.753 min, execution result 0
# ✅ Stage:5 completed successfully
# CPU times: user 544 ms, sys: 239 ms, total: 783 ms
# Wall time: 46.8 s

# %% [markdown]
# ### 7.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print ("Duplicate chunks removed  by fuzzy-dedupe:  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (8, 18)
# Output data dimensions (rows x columns)=  (6, 18)
# Duplicate chunks removed  by fuzzy-dedupe:   2
#     filename  num_pages  num_tables  num_doc_elements  ext  \
# 0  earth.pdf          1           0                11  pdf
# 1  earth.pdf          1           0                11  pdf
# 2   mars.pdf          1           0                11  pdf
# 3   mars.pdf          1           0                11  pdf
# 4   mars.pdf          1           0                11  pdf
# 5   mars.pdf          1           0                11  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 2  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 3  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 4  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 5  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 2  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 3  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 4  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 5  2024-09-26T07:27:16.355166          9.173448        mars.pdf
#
#                      source_document_id  \
# 0  882b0ae9-00ff-4971-8462-c4e35bac569c
# 1  882b0ae9-00ff-4971-8462-c4e35bac569c
# 2  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 3  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 4  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 5  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
#
#                                             contents    doc_jsonpath  \
# 0  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 1  Earth\nBasic facts about Earth:\n· Distance fr...  $.main-text[6]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 3  Solar System\nFor more details about the Solar...  $.main-text[3]
# 4  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 5  Basic facts about Mars:\n· Distance from the S...  $.main-text[6]
#
#    page_number                                               bbox  \
# 0            1  [132.91053772, 512.46295166, 477.84887695, 534...
# 1            1  [133.30151367, 494.86206055, 240.17156982, 505...
# 2            1  [132.84518433, 588.96014404, 479.40917969, 623...
# 3            1  [133.18510437, 570.83258057, 374.99838257, 581...
# 4            1  [132.87440491, 500.84011841, 477.48345947, 534...
# 5            1  [133.2026062, 482.90710449, 237.04431152, 493....
#
#                                          document_id  chunk_id  chunk_hash
# 0  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...         6          -1
# 1  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...         7          -1
# 2  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...         0           4
# 3  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...         1           5
# 4  a31663e06fac41470ecc459f5a58658a3f9997d7801053...         2          -1
# 5  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...         3          -1

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 1  earth.pdf  Earth\nBasic facts about Earth:\n· Distance fr...
# 2   mars.pdf  Solar System\nOur solar system is a vast and f...
# 3   mars.pdf  Solar System\nFor more details about the Solar...
# 4   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 5   mars.pdf  Basic facts about Mars:\n· Distance from the S...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== earth.pdf ===========
# -------Chunk 0------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 1------
# Earth
# Basic facts about Earth:
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# · Moons: One moon, called Luna or simply "the Moon".
# -------
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 3------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------

# %% [markdown]
# ### 7.4- Understanding the output
#
# So we started with 7 rows and ended up with 6.  Fuzzy dedupe removed the following **very similar** chunk.
#
# These are pretty similar chunks except for the words 'the' and 'our'
#
# **earth.pdf**
#
# `For more details about *our* Solar system see Chapter 1.`
#
# **mars.pdf**
#
# `For more details about *the* Solar system see Chapter 1.`
#
# Pretty neat, eh? 👏
#
# ### Configuring Fuzzy de-dupe
#
# You can tweak fuzzy dedupe by tweaking the following parameters
#
# ```python
# # fuzzy parameters
#     "fdedup_num_permutations": 64,
#     "fdedup_threshold": 0.7, #  (default 0.8)
#     "fdedup_shingles_size": 5,
#     "fdedup_delimiters": " "
# ```
#
# In our case, we set `fdedup_threshold` parameter to 0.7.

# %% [markdown]
# ## Step-8:   Text encoding
#
# Encode text for the vector storage.

# %% [markdown]
# ### 8.1 - Set Input/output Folder

# %%
STAGE  = 6

input_folder = output_fuzzy_dedupe_dir # previous output folder is the input folder for the current stage
output_folder =  output_embeddings_dir

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-6: Processing input='output/05_fuzzy_dedupe_out' --> output='output/06_embeddings_out'

# %% [markdown]
# ### 8.2 - Execute

# %%
# %%time

from text_encoder_transform_ray import TextEncoderRayTransformConfiguration

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # text_encoder
    "text_encoder_model_name": MY_CONFIG.EMBEDDING_MODEL,
}

sys.argv = ParamsUtils.dict_to_req(d=params)
# create launcher
launcher = RayTransformLauncher(TextEncoderRayTransformConfiguration())
# Launch the ray actor(s) to process the input

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 07:29:45 INFO - text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'sentence-transformers/all-MiniLM-L6-v2'}
# INFO:text_encoder_transformcfg:text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'sentence-transformers/all-MiniLM-L6-v2'}
# 07:29:45 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 07:29:45 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 07:29:45 INFO - number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# INFO:data_processing_ray.runtime.ray.execution_configuration:number of workers 2 worker options {'num_cpus': 0.3, 'max_restarts': -1}
# 07:29:45 INFO - actor creation delay 0
# INFO:data_processing_ray.runtime.ray.execution_configuration:actor creation delay 0
# 07:29:45 INFO - job details {'job category': 'preprocessing', 'job name': 'text_encoder', 'job type': 'ray', 'job id': 'job_id'}
# INFO:data_processing_ray.runtime.ray.execution_configuration:job details {'job category': 'preprocessing', 'job name': 'text_encoder', 'job type': 'ray', 'job id': 'job_id'}
# 07:29:45 INFO - data factory data_ is using local data access: input_folder - output/05_fuzzy_dedupe_out output_folder - output/06_embeddings_out
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ is using local data access: input_folder - output/05_fuzzy_dedupe_out output_folder - output/06_embeddings_out
# 07:29:45 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ max_files -1, n_sample -1
# 07:29:45 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_baseb14bb0e9-0fec-470b-94ad-a45c8ee43347:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 07:29:45 INFO - Running locally
# INFO:data_processing_ray.runtime.ray.transform_launcher:Running locally
# 2024-09-26 07:29:49,306	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=7329) 2024-09-26 07:29:57.053973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (orchestrate pid=7329) 2024-09-26 07:29:57.080873: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (orchestrate pid=7329) 2024-09-26 07:29:57.088712: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (orchestrate pid=7329) 2024-09-26 07:29:58.697253: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (orchestrate pid=7329) 07:30:00 INFO - orchestrator started at 2024-09-26 07:30:00
# (orchestrate pid=7329) 07:30:00 INFO - Number of files is 2, source profile {'max_file_size': 0.009774208068847656, 'min_file_size': 0.009067535400390625, 'total_file_size': 0.01884174346923828}
# (orchestrate pid=7329) 07:30:00 INFO - Cluster resources: {'cpus': 2, 'gpus': 0, 'memory': 7.427989197894931, 'object_store': 3.713994598016143}
# (orchestrate pid=7329) 07:30:00 INFO - Number of workers - 2 with {'num_cpus': 0.3, 'max_restarts': -1} each
# (orchestrate pid=7329) 07:30:00 INFO - Completed 0 files (0.0%)  in 0.001 min. Waiting for completion
# (RayTransformFileProcessor pid=7487) 2024-09-26 07:30:12.177413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (RayTransformFileProcessor pid=7487) 2024-09-26 07:30:12.256078: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (RayTransformFileProcessor pid=7487) 2024-09-26 07:30:12.279689: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (RayTransformFileProcessor pid=7521) 2024-09-26 07:30:12.570361: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (RayTransformFileProcessor pid=7487) 2024-09-26 07:30:14.914771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (orchestrate pid=7329) 07:30:22 INFO - Completed processing 2 files in 0.365 min
# (orchestrate pid=7329) 07:30:22 INFO - done flushing in 0.007 sec
# (RayTransformFileProcessor pid=7521) 2024-09-26 07:30:12.646670: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (RayTransformFileProcessor pid=7521) 2024-09-26 07:30:12.659955: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (RayTransformFileProcessor pid=7521) 2024-09-26 07:30:15.112478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 07:30:32 INFO - Completed execution in 0.783 min, execution result 0
# INFO:data_processing_ray.runtime.ray.transform_launcher:Completed execution in 0.783 min, execution result 0
# ✅ Stage:6 completed successfully
# CPU times: user 4.51 s, sys: 854 ms, total: 5.36 s
# Wall time: 54.8 s

# %% [markdown]
# ### 8.3 - Inspect Generated output
#
# You will see a column called `embeddings` added at the end.  This the text content converted into vectors or embeddings.  We used the model `sentence-transformers/all-MiniLM-L6-v2`

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (6, 18)
# Output data dimensions (rows x columns)=  (6, 19)
#     filename  num_pages  num_tables  num_doc_elements  ext  \
# 0  earth.pdf          1           0                11  pdf
# 1  earth.pdf          1           0                11  pdf
# 2   mars.pdf          1           0                11  pdf
# 3   mars.pdf          1           0                11  pdf
# 4   mars.pdf          1           0                11  pdf
# 5   mars.pdf          1           0                11  pdf
#
#                                                 hash  size  \
# 0  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 1  18713f970989055625bef22209b6f4b6830b9ca22046bf...  2686
# 2  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 3  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 4  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
# 5  8edd5dfbf888777120b528a5d8998f2757d006df0eaef7...  2800
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 1  2024-09-26T07:27:16.365657          8.991802       earth.pdf
# 2  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 3  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 4  2024-09-26T07:27:16.355166          9.173448        mars.pdf
# 5  2024-09-26T07:27:16.355166          9.173448        mars.pdf
#
#                      source_document_id  \
# 0  882b0ae9-00ff-4971-8462-c4e35bac569c
# 1  882b0ae9-00ff-4971-8462-c4e35bac569c
# 2  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 3  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 4  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
# 5  2e42c0c7-69f7-4582-8aef-8dd493cfda1a
#
#                                             contents    doc_jsonpath  \
# 0  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 1  Earth\nBasic facts about Earth:\n· Distance fr...  $.main-text[6]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 3  Solar System\nFor more details about the Solar...  $.main-text[3]
# 4  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 5  Basic facts about Mars:\n· Distance from the S...  $.main-text[6]
#
#    page_number                                               bbox  \
# 0            1  [132.91053772, 512.46295166, 477.84887695, 534...
# 1            1  [133.30151367, 494.86206055, 240.17156982, 505...
# 2            1  [132.84518433, 588.96014404, 479.40917969, 623...
# 3            1  [133.18510437, 570.83258057, 374.99838257, 581...
# 4            1  [132.87440491, 500.84011841, 477.48345947, 534...
# 5            1  [133.2026062, 482.90710449, 237.04431152, 493....
#
#                                          document_id  chunk_id  chunk_hash  \
# 0  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...         6          -1
# 1  189a221704d17feeb96b1b1ef60a2a2445459848cd8e8f...         7          -1
# 2  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...         0           4
# 3  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...         1           5
# 4  a31663e06fac41470ecc459f5a58658a3f9997d7801053...         2          -1
# 5  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...         3          -1
#
#                                           embeddings
# 0  [0.0724358, -0.058001805, -0.01977186, -0.0243...
# 1  [0.091821924, 0.015197907, 0.07716932, 0.01711...
# 2  [0.0077404897, -0.020559434, 0.026426662, 0.01...
# 3  [-0.051861413, 0.0035226392, 0.030617053, 0.04...
# 4  [0.07728298, 0.024971062, -0.04318075, 0.05809...
# 5  [0.1059802, 0.025460616, 0.02362733, 0.0390564...

# %% [markdown]
# ## Step-9: Copy output to final output dir

# %%
import shutil

shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER_FINAL, ignore_errors=True)
shutil.copytree(src=output_folder, dst=MY_CONFIG.OUTPUT_FOLDER_FINAL)

print (f"✅ Copied output from '{output_folder}' --> '{MY_CONFIG.OUTPUT_FOLDER_FINAL}'")
# Out:
# ✅ Copied output from 'output/06_embeddings_out' --> 'output/output_final'
